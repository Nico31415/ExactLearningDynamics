# %% [markdown]
# Suppose $W_1^T W_1 - W_2 W_2^2 = \lambda I$.
#
# Consider
#
# $$
# F' = \begin{bmatrix}
#
# \frac{\lambda}{2} I & \tilde{\Sigma_{yx}}^T \\
# \tilde{\Sigma_{yx}}^T & -\frac{\lambda}{2} I
#
# \end{bmatrix}
# $$
#
# We can show that:
#
# $\tau \frac{d}{dt} (QQ^T) = F' QQ^T + QQ^T F' - (QQ^T)^2$
#
# This equation has well known solution (from paper):
#
# $Q(t)Q(t)^T =  e^{F' \frac{t}{\tau}} Q(0)[I + \frac{1}{2} Q(0)^T (e^{F' \frac{t}{\tau}} F'^{-1} e^{F' \frac{t}{\tau}}) Q(0)]^{-1} Q(0)^T e^{F' \frac{t}{\tau}}$
#
#
# We try to find an interpretable solution.
#
# Note that
#
# $$
# F' = F + \begin{bmatrix}
#
# \frac{\lambda}{2} I & 0\\
# 0 & -\frac{\lambda}{2} I
#
# \end{bmatrix}
# $$
#
# In the previous paper it has been shown that the matrix F is diagonalisable:
#
# If we have $\tilde{\Sigma_{yx}} = \tilde{U} \tilde{S} \tilde{V}^T$ (Singular Value Decomposition)
#
# $$
# F = \frac{1}{2}
#
# \begin{bmatrix}
#
# \tilde{V} & \tilde{V}\\
# \tilde{U} & -\tilde{U}
#
# \end{bmatrix}
#
# \begin{bmatrix}
#
# \tilde{S} & 0\\
# 0 & -\tilde{S}
#
# \end{bmatrix}
#
# \begin{bmatrix}
#
# \tilde{V} & \tilde{V}\\
# \tilde{U} & -\tilde{U}
#
# \end{bmatrix}^T
#
# $$
#
# Hence
#
# $$
# F' = \frac{1}{2} \begin{bmatrix}
#
# \tilde{V} & \tilde{V}\\
# \tilde{U} & -\tilde{U}
#
# \end{bmatrix}
#
# \begin{bmatrix}
#
# \tilde{S} & 0\\
# 0 & -\tilde{S}
#
# \end{bmatrix}
#
# \begin{bmatrix}
#
# \tilde{V} & \tilde{V}\\
# \tilde{U} & -\tilde{U}
#
# \end{bmatrix}^T
#
# +
#
#
#
# \begin{bmatrix}
# \frac{\lambda}{2} I & 0\\
# 0 & -\frac{\lambda}{2} I
# \end{bmatrix}
#
#
# $$

# %% [markdown]
# Now we simplify some expressions:
#
# Let
#
# $$
# O = \frac{1}{\sqrt{2}} \begin{bmatrix}
#
# \tilde{V} & \tilde{V}\\
# \tilde{U} & -\tilde{U}
#
# \end{bmatrix}
# $$
#
# $$
# \Lambda = \begin{bmatrix}
# \tilde{S} & 0\\
# 0 & -\tilde{S}
# \end{bmatrix}
# $$
#
# $$
# A = \begin{bmatrix}
# \frac{\lambda}{2} I & 0\\
# 0 & -\frac{\lambda}{2} I
# \end{bmatrix}
# $$
#
# $F' = O \Lambda O^T + A$
#
# Hence
#
# $e^{F' \frac{t}{\tau}} = O e^{\Lambda \frac{t}{\tau}} O^T e^{A \frac{t}{\tau}}$

# %% [markdown]
# Now:
#
# $$
#
# O^T e^{A \frac{t}{\tau}} Q(0) = \frac{1}{\sqrt{2}} \begin{bmatrix}
#
# \tilde{V} & \tilde{V}\\
# \tilde{U} & -\tilde{U}
#
# \end{bmatrix}
#
#
# \begin{bmatrix}
# e^{\frac{\lambda}{2} \frac{t}{\tau}} I & 0\\
# 0 & e^{ - \frac{\lambda}{2} \frac{t}{\tau}} I
# \end{bmatrix}
#
# \begin{bmatrix}
# V \sqrt{A(0)} R^T \\
# U \sqrt{A(0)} R^T
# \end{bmatrix}
#
#
#
#
#
# $$

# %% [markdown]
# $$
# O^T e^{A \frac{t}{\tau}} Q(0) = \frac{1}{\sqrt{2}} \begin{bmatrix}
#
# e^{\frac{\lambda t}{2 \tau}} \tilde{V}^T V \sqrt{A(0)} R^T + e^{\frac{ - \lambda t}{2 \tau}} \tilde{U}^T U \sqrt{A(0)} R^T \\
# e^{\frac{\lambda t}{2 \tau}} \tilde{V}^T V \sqrt{A(0)} R^T - e^{\frac{ - \lambda t}{2 \tau}} \tilde{U}^T U \sqrt{A(0)} R^T
#
# \end{bmatrix}
# $$

# %% [markdown]
# $$
# O e^{\Lambda \frac{t}{\tau}} = \frac{1}{\sqrt{2}}
#
# \begin{bmatrix}
# \tilde{V} & \tilde{V} \\
# \tilde{U} & -\tilde{U}
# \end{bmatrix}
#
# \begin{bmatrix}
# e^{\tilde{S} \frac{t}{\tau}} & 0 \\
# 0 & e^{- \tilde{S} \frac{t}{\tau}} \\
# \end{bmatrix}
#
#
# $$
#
# $$
# O e^{\Lambda \frac{t}{\tau}} = \frac{1}{\sqrt{2}}
#
# \begin{bmatrix}
# \tilde{V} e^{\tilde{S} \frac{t}{\tau}} & \tilde{V} e^{- \tilde{S} \frac{t}{\tau}} \\
# \tilde{U} e^{\tilde{S} \frac{t}{\tau}} & -\tilde{U} e^{-\tilde{S} \frac{t}{\tau}}
# \end{bmatrix}
# $$

# %% [markdown]
# $$
# O e^{\Lambda \frac{t}{\tau}} O^T e^{A \frac{t}{\tau}} Q(0) =
#
# \frac{1}{\sqrt{2}}
#
# \begin{bmatrix}
# \tilde{V} e^{\tilde{S} \frac{t}{\tau}} & \tilde{V} e^{- \tilde{S} \frac{t}{\tau}} \\
# \tilde{U} e^{\tilde{S} \frac{t}{\tau}} & -\tilde{U} e^{-\tilde{S} \frac{t}{\tau}}
# \end{bmatrix}
#
# \frac{1}{\sqrt{2}} \begin{bmatrix}
#
# e^{\frac{\lambda t}{2 \tau}} \tilde{V}^T V \sqrt{A(0)} R^T + e^{\frac{ - \lambda t}{2 \tau}} \tilde{U}^T U \sqrt{A(0)} R^T \\
# e^{\frac{\lambda t}{2 \tau}} \tilde{V}^T V \sqrt{A(0)} R^T - e^{\frac{ - \lambda t}{2 \tau}} \tilde{U}^T U \sqrt{A(0)} R^T
#
# \end{bmatrix}
# $$
#
# $$
#
# O e^{\Lambda \frac{t}{\tau}} O^T e^{A \frac{t}{\tau}} Q(0) =
#
# \frac{1}{2} \begin{bmatrix}
#
# \tilde{V} (e^{\tilde{S} \frac{t}{\tau}} + e^{-\tilde{S} \frac{t}{\tau}}) e^{\frac{\lambda t}{2 \tau}} \tilde{V}^T V \sqrt{A(0)} R^T + \tilde{V} (e^{\tilde{S} \frac{t}{\tau}} - e^{-\tilde{S} \frac{t}{\tau}}) e^{-\frac{\lambda t}{2 \tau}} \tilde{U}^T U \sqrt{A(0)} R^T \\
#
# \tilde{U} (e^{\tilde{S} \frac{t}{\tau}} - e^{-\tilde{S} \frac{t}{\tau}}) e^{\frac{\lambda t}{2 \tau}} \tilde{V}^T V \sqrt{A(0)} R^T + \tilde{U} (e^{\tilde{S} \frac{t}{\tau}} + e^{-\tilde{S} \frac{t}{\tau}}) e^{-\frac{\lambda t}{2 \tau}} \tilde{U}^T U \sqrt{A(0)} R^T
#
# \end{bmatrix}
# $$
#
# $$
#
# O e^{\Lambda \frac{t}{\tau}} O^T e^{A \frac{t}{\tau}} Q(0) =
#
# \frac{1}{2} \begin{bmatrix}
#
# (\tilde{V} e^{\tilde{S} \frac{t}{\tau}} (e^{\frac{\lambda t}{2 \tau}} \tilde{V}^T V + e^{-\frac{\lambda t}{2 \tau}} \tilde{U}^T U) + \tilde{V} e^{-\tilde{S} \frac{t}{\tau}} (e^{\frac{\lambda t}{2 \tau}} \tilde{V}^T V - e^{-\frac{\lambda t}{2 \tau}} \tilde{U}^T U) \sqrt{A(0)} R^T \\
#
# (\tilde{U} e^{\tilde{S} \frac{t}{\tau}} (e^{\frac{\lambda t}{2 \tau}} \tilde{V}^T V + e^{-\frac{\lambda t}{2 \tau}} \tilde{U}^T U) - \tilde{U} e^{-\tilde{S} \frac{t}{\tau}} (e^{\frac{\lambda t}{2 \tau}} \tilde{V}^T V - e^{-\frac{\lambda t}{2 \tau}} \tilde{U}^T U) \sqrt{A(0)} R^T
#
#
# \end{bmatrix}
# $$

# %% [markdown]
# Now,
#
# $F'^{-1} = (A + O \Lambda O^ T)^{-1} := X$
#
# IDEA: WE ONLY  NEED TO COPMUTE THIS VALUE ONCE, SO IT DOESNT MATTER IF IT IS THAT COMPLICATED? THE EXPONENTIALS ARE RELATIVELY STRAIGHTFORWARD TO COMPUTE WHICH IS THE MOST IMPORTANT.
#
# By Woodbury identity (https://en.wikipedia.org/wiki/Woodbury_matrix_identity) this is equal to:
#
# $* = A^{-1} - A^{-1} O (\Lambda^{-1} + O^T A^{-1} O)^{-1} O A^{-1} $
#
# we also know $A^{-1} = \frac{4}{\lambda^2}A$
#
# Hence
#
# $* =  \frac{4}{\lambda^2}A -  (\frac{4}{\lambda^2})^2 A O (\Lambda^{-1} + \frac{4}{\lambda^2} O^T A O)^{-1} O A $
#
# HOW IS THIS HELPFUL??

# %% [markdown]
# $I + \frac{1}{2}Q(0)^T (e^{F' \frac{t}{\tau}} F'^{-1} e^{F' \frac{t}{\tau}} - F'^{-1}) Q(0)$
#
# = $I + \frac{1}{2}Q(0)^T e^{F' \frac{t}{\tau}} (F'^{-1}  - e^{- F' \frac{t}{\tau}} F'^{-1} e^{- F' \frac{t}{\tau}})e^{F' \frac{t}{\tau}} Q(0) $
#
# Let's define $X(t) := (F'^{-1}  - e^{- F' \frac{t}{\tau}} F'^{-1} e^{- F' \frac{t}{\tau}})$
#
# Then the expression becomes:
#
# = $I + \frac{1}{2}Q(0)^T e^{F' \frac{t}{\tau}} X(t) e^{F' \frac{t}{\tau}} Q(0) $
#
# Simplifying:
#
#
# $$
#
# = I + \frac{1}{2} \frac{1}{2} \begin{bmatrix}
#
# (\tilde{V} e^{\tilde{S} \frac{t}{\tau}} (e^{\frac{\lambda t}{2 \tau}} \tilde{V}^T V + e^{-\frac{\lambda t}{2 \tau}} \tilde{U}^T U) + \tilde{V} e^{-\tilde{S} \frac{t}{\tau}} (e^{\frac{\lambda t}{2 \tau}} \tilde{V}^T V - e^{-\frac{\lambda t}{2 \tau}} \tilde{U}^T U) \sqrt{A(0)} R^T \\
#
# (\tilde{U} e^{\tilde{S} \frac{t}{\tau}} (e^{\frac{\lambda t}{2 \tau}} \tilde{V}^T V + e^{-\frac{\lambda t}{2 \tau}} \tilde{U}^T U) - \tilde{U} e^{-\tilde{S} \frac{t}{\tau}} (e^{\frac{\lambda t}{2 \tau}} \tilde{V}^T V - e^{-\frac{\lambda t}{2 \tau}} \tilde{U}^T U) \sqrt{A(0)} R^T
#
#
# \end{bmatrix}^T
#
# X(t)
#
# \frac{1}{2} \begin{bmatrix}
#
# (\tilde{V} e^{\tilde{S} \frac{t}{\tau}} (e^{\frac{\lambda t}{2 \tau}} \tilde{V}^T V + e^{-\frac{\lambda t}{2 \tau}} \tilde{U}^T U) + \tilde{V} e^{-\tilde{S} \frac{t}{\tau}} (e^{\frac{\lambda t}{2 \tau}} \tilde{V}^T V - e^{-\frac{\lambda t}{2 \tau}} \tilde{U}^T U) \sqrt{A(0)} R^T \\
#
# (\tilde{U} e^{\tilde{S} \frac{t}{\tau}} (e^{\frac{\lambda t}{2 \tau}} \tilde{V}^T V + e^{-\frac{\lambda t}{2 \tau}} \tilde{U}^T U) - \tilde{U} e^{-\tilde{S} \frac{t}{\tau}} (e^{\frac{\lambda t}{2 \tau}} \tilde{V}^T V - e^{-\frac{\lambda t}{2 \tau}} \tilde{U}^T U) \sqrt{A(0)} R^T
#
#
# \end{bmatrix}
#
# $$
#
# $$
#
# = I + \frac{1}{8} \begin{bmatrix}
#
# (\tilde{V} e^{\tilde{S} \frac{t}{\tau}} (e^{\frac{\lambda t}{2 \tau}} \tilde{V}^T V + e^{-\frac{\lambda t}{2 \tau}} \tilde{U}^T U) + \tilde{V} e^{-\tilde{S} \frac{t}{\tau}} (e^{\frac{\lambda t}{2 \tau}} \tilde{V}^T V - e^{-\frac{\lambda t}{2 \tau}} \tilde{U}^T U) \sqrt{A(0)} R^T \\
#
# (\tilde{U} e^{\tilde{S} \frac{t}{\tau}} (e^{\frac{\lambda t}{2 \tau}} \tilde{V}^T V + e^{-\frac{\lambda t}{2 \tau}} \tilde{U}^T U) - \tilde{U} e^{-\tilde{S} \frac{t}{\tau}} (e^{\frac{\lambda t}{2 \tau}} \tilde{V}^T V - e^{-\frac{\lambda t}{2 \tau}} \tilde{U}^T U) \sqrt{A(0)} R^T
#
#
# \end{bmatrix}^T
#
# X(t)
#
# \begin{bmatrix}
#
# (\tilde{V} e^{\tilde{S} \frac{t}{\tau}} (e^{\frac{\lambda t}{2 \tau}} \tilde{V}^T V + e^{-\frac{\lambda t}{2 \tau}} \tilde{U}^T U) + \tilde{V} e^{-\tilde{S} \frac{t}{\tau}} (e^{\frac{\lambda t}{2 \tau}} \tilde{V}^T V - e^{-\frac{\lambda t}{2 \tau}} \tilde{U}^T U) \sqrt{A(0)} R^T \\
#
# (\tilde{U} e^{\tilde{S} \frac{t}{\tau}} (e^{\frac{\lambda t}{2 \tau}} \tilde{V}^T V + e^{-\frac{\lambda t}{2 \tau}} \tilde{U}^T U) - \tilde{U} e^{-\tilde{S} \frac{t}{\tau}} (e^{\frac{\lambda t}{2 \tau}} \tilde{V}^T V - e^{-\frac{\lambda t}{2 \tau}} \tilde{U}^T U) \sqrt{A(0)} R^T
#
#
# \end{bmatrix}
#
# $$

# %% [markdown]
# Which is:
# $$
#
# I + \frac{1}{8}
#
# \begin{bmatrix}
#
# (\tilde{V} e^{\tilde{S} \frac{t}{\tau}} e^{\frac{\lambda t}{2 \tau}} (\tilde{V}^T V + e^{-\frac{\lambda t}{\tau}} \tilde{U}^T U) +  \tilde{V} e^{-\tilde{S} \frac{t}{\tau}} e^{\frac{\lambda t}{2 \tau}} (\tilde{V}^T V - e^{-\frac{\lambda t}{\tau}} \tilde{U}^T U) \sqrt{A(0)} R^T \\
#
# (\tilde{U} e^{\tilde{S} \frac{t}{\tau}}e^{\frac{\lambda t}{2 \tau}} (\tilde{V}^T V + e^{-\frac{\lambda t}{\tau}} \tilde{U}^T U) - \tilde{U} e^{-\tilde{S} \frac{t}{\tau}} e^{\frac{\lambda t}{2 \tau}} (\tilde{V}^T V - e^{-\frac{\lambda t}{\tau}} \tilde{U}^T U) \sqrt{A(0)} R^T
#
#
# \end{bmatrix}^T
#
# X(t)
#
# \begin{bmatrix}
#
# (\tilde{V} e^{\tilde{S} \frac{t}{\tau}} e^{\frac{\lambda t}{2 \tau}} (\tilde{V}^T V + e^{-\frac{\lambda t}{\tau}} \tilde{U}^T U) +  \tilde{V} e^{-\tilde{S} \frac{t}{\tau}} e^{\frac{\lambda t}{2 \tau}} (\tilde{V}^T V - e^{-\frac{\lambda t}{\tau}} \tilde{U}^T U) \sqrt{A(0)} R^T \\
#
# (\tilde{U} e^{\tilde{S} \frac{t}{\tau}}e^{\frac{\lambda t}{2 \tau}} (\tilde{V}^T V + e^{-\frac{\lambda t}{\tau}} \tilde{U}^T U) - \tilde{U} e^{-\tilde{S} \frac{t}{\tau}} e^{\frac{\lambda t}{2 \tau}} (\tilde{V}^T V - e^{-\frac{\lambda t}{\tau}} \tilde{U}^T U) \sqrt{A(0)} R^T
#
#
# \end{bmatrix}
# $$

# %% [markdown]
# Define $B = e^{-\frac{\lambda t} {\tau}} U^T \tilde{U} + V^T \tilde{V}$ and $C = e^{-\frac{\lambda t} {\tau}} U^T \tilde{U} - V^T \tilde{V}$

# %% [markdown]
# Centre becomes:
# $$
# I + \frac{1}{8}
#
# \begin{bmatrix}
#
# \tilde{V} e^{\tilde{S} \frac{t}{\tau}} e^{\frac{\lambda t}{2 \tau}} (B^T -  C^T) \sqrt{A(0)} R^T \\
#
# \tilde{U} e^{\tilde{S} \frac{t}{\tau}}e^{\frac{\lambda t}{2 \tau}} (B^T + C^T) \sqrt{A(0)} R^T
#
#
# \end{bmatrix}^T
#
# X(t)
#
# \begin{bmatrix}
#
# \tilde{V} e^{\tilde{S} \frac{t}{\tau}} e^{\frac{\lambda t}{2 \tau}} (B^T -  C^T) \sqrt{A(0)} R^T \\
#
# \tilde{U} e^{\tilde{S} \frac{t}{\tau}}e^{\frac{\lambda t}{2 \tau}} (B^T + C^T) \sqrt{A(0)} R^T
#
#
# \end{bmatrix}
# $$

# %% [markdown]
# Left side becomes:
#
# $$
#
# \frac{1}{2}
#
# \begin{bmatrix}
#
# \tilde{V} e^{\tilde{S} \frac{t}{\tau}} e^{\frac{\lambda t}{2 \tau}} (B^T -  C^T) \sqrt{A(0)} R^T \\
#
# \tilde{U} e^{\tilde{S} \frac{t}{\tau}}e^{\frac{\lambda t}{2 \tau}} (B^T + C^T) \sqrt{A(0)} R^T
#
#
# \end{bmatrix}
#
# $$
#
#
# Which is equal to:
#
# $$
#
# \frac{1}{2}
#
# \begin{bmatrix}
#
# B^T - C^T && B^T + C^T
#
# \end{bmatrix}
#
# \begin{bmatrix}
# \tilde{V} \\
# \tilde{U}
# \end{bmatrix}
#
# e^{\tilde{S} \frac{t}{\tau}} e^{\frac{\lambda t}{2 \tau}}
#
# \sqrt{A(0)} R^T
# $$
#
# Equal to:
#
# $$
# \frac{1}{2}
#
# \begin{bmatrix}
#
# B - C \\
#  B + C
#
# \end{bmatrix}^T
#
# \begin{bmatrix}
# \tilde{V} \\
# \tilde{U}
# \end{bmatrix}
#
# e^{\tilde{S} \frac{t}{\tau}} e^{\frac{\lambda t}{2 \tau}}
#
# \sqrt{A(0)} R^T
# $$

# %% [markdown]
# So whole equation:
#
#
# $$
#
# \frac{1}{2}
#
# (\frac{1}{2}
#
# \begin{bmatrix}
#
# B - C \\
#  B + C
#
# \end{bmatrix}^T
#
# \begin{bmatrix}
# \tilde{V} \\
# \tilde{U}
# \end{bmatrix}
#
# e^{\tilde{S} \frac{t}{\tau}} e^{\frac{\lambda t}{2 \tau}}
#
# \sqrt{A(0)} R^T)
#
#
#
# (I + \frac{1}{8}
#
# (\begin{bmatrix}
#
# B - C \\
#  B + C
#
# \end{bmatrix}^T
#
# \begin{bmatrix}
# \tilde{V} \\
# \tilde{U}
# \end{bmatrix}
#
# e^{\tilde{S} \frac{t}{\tau}} e^{\frac{\lambda t}{2 \tau}}
#
# \sqrt{A(0)} R^T)^T
#
# X(t)
#
# (\begin{bmatrix}
#
# B - C \\
#  B + C
#
# \end{bmatrix}^T
#
# \begin{bmatrix}
# \tilde{V} \\
# \tilde{U}
# \end{bmatrix}
#
# e^{\tilde{S} \frac{t}{\tau}} e^{\frac{\lambda t}{2 \tau}}
#
# \sqrt{A(0)} R^T))^{-1}
#
#
# (\frac{1}{2}
#
# \begin{bmatrix}
#
# B - C \\
#  B + C
#
# \end{bmatrix}^T
#
# \begin{bmatrix}
# \tilde{V} \\
# \tilde{U}
# \end{bmatrix}
#
# e^{\tilde{S} \frac{t}{\tau}} e^{\frac{\lambda t}{2 \tau}}
# \sqrt{A(0)} R^T)^T
#
# $$

# %% [markdown]
# Which is equal to:
#
#
# $$
#
# \frac{1}{2}
#
#
#
# (\begin{bmatrix}
#
# B - C \\
#  B + C
#
# \end{bmatrix}^T
#
# \begin{bmatrix}
# \tilde{V} \\
# \tilde{U}
# \end{bmatrix}
#
# e^{\tilde{S} \frac{t}{\tau}} e^{\frac{\lambda t}{2 \tau}}
# \sqrt{A(0)} R^T)
#
#
#
# (8 I +
#
# \begin{bmatrix}
#
# \tilde{V} e^{\tilde{S} \frac{t}{\tau}} e^{\frac{\lambda t}{2 \tau}} (B^T -  C^T) \sqrt{A(0)} R^T \\
#
# \tilde{U} e^{\tilde{S} \frac{t}{\tau}}e^{\frac{\lambda t}{2 \tau}} (B^T + C^T) \sqrt{A(0)} R^T
#
#
# \end{bmatrix}^T
#
# X(t)
#
# \begin{bmatrix}
#
# \tilde{V} e^{\tilde{S} \frac{t}{\tau}} e^{\frac{\lambda t}{2 \tau}} (B^T -  C^T) \sqrt{A(0)} R^T \\
#
# \tilde{U} e^{\tilde{S} \frac{t}{\tau}}e^{\frac{\lambda t}{2 \tau}} (B^T + C^T) \sqrt{A(0)} R^T
#
#
# \end{bmatrix})^{-1}
#
#
#
#
# (\begin{bmatrix}
#
# B - C \\
#  B + C
#
# \end{bmatrix}^T
#
# \begin{bmatrix}
# \tilde{V} \\
# \tilde{U}
# \end{bmatrix}
#
# e^{\tilde{S} \frac{t}{\tau}} e^{\frac{\lambda t}{2 \tau}}
# \sqrt{A(0)} R^T)^T
#
# $$

# %% [markdown]
# Taking A's and R's inside the inverse:
#
#
# $$
#
# \frac{1}{2}
#
# (\begin{bmatrix}
#
# B - C \\
#  B + C
#
# \end{bmatrix}^T
#
# \begin{bmatrix}
# \tilde{V} \\
# \tilde{U}
# \end{bmatrix}
#
# e^{\tilde{S} \frac{t}{\tau}} e^{\frac{\lambda t}{2 \tau}})
#
#
#
#
# (8 A(0)^{-1} +
#
# A(0)^{-\frac{1}{2}} R^T
# \begin{bmatrix}
#
# \tilde{V} e^{\tilde{S} \frac{t}{\tau}} e^{\frac{\lambda t}{2 \tau}} (B^T -  C^T) \sqrt{A(0)} R^T \\
#
# \tilde{U} e^{\tilde{S} \frac{t}{\tau}}e^{\frac{\lambda t}{2 \tau}} (B^T + C^T) \sqrt{A(0)} R^T
#
#
# \end{bmatrix}^T
#
# X(t)
#
# \begin{bmatrix}
#
# \tilde{V} e^{\tilde{S} \frac{t}{\tau}} e^{\frac{\lambda t}{2 \tau}} (B^T -  C^T) \sqrt{A(0)} R^T \\
#
# \tilde{U} e^{\tilde{S} \frac{t}{\tau}}e^{\frac{\lambda t}{2 \tau}} (B^T + C^T) \sqrt{A(0)} R^T
#
#
# \end{bmatrix}
# R A(0)^{-\frac{1}{2}})^{-1}
#
# (\begin{bmatrix}
#
# B - C \\
#  B + C
#
# \end{bmatrix}^T
#
# \begin{bmatrix}
# \tilde{V} \\
# \tilde{U}
# \end{bmatrix}
#
# e^{\tilde{S} \frac{t}{\tau}} e^{\frac{\lambda t}{2 \tau}})^T
#
#
#
#
# $$

# %% [markdown]
# Simplifying:
#
#
#
#
# $$
#
# \frac{1}{2}
#
# (\begin{bmatrix}
#
# B - C \\
#  B + C
#
# \end{bmatrix}^T
#
# \begin{bmatrix}
# \tilde{V} \\
# \tilde{U}
# \end{bmatrix}
#
# e^{\tilde{S} \frac{t}{\tau}} e^{\frac{\lambda t}{2 \tau}})
#
#
#
#
# (8 A(0)^{-1} +
#
#
# \begin{bmatrix}
#
# \tilde{V} e^{\tilde{S} \frac{t}{\tau}} e^{\frac{\lambda t}{2 \tau}} (B^T -  C^T)  \\
#
# \tilde{U} e^{\tilde{S} \frac{t}{\tau}}e^{\frac{\lambda t}{2 \tau}} (B^T + C^T)
#
#
# \end{bmatrix}^T
#
# X(t)
#
# \begin{bmatrix}
#
# \tilde{V} e^{\tilde{S} \frac{t}{\tau}} e^{\frac{\lambda t}{2 \tau}} (B^T -  C^T)  \\
#
# \tilde{U} e^{\tilde{S} \frac{t}{\tau}}e^{\frac{\lambda t}{2 \tau}} (B^T + C^T)
#
#
# \end{bmatrix}
#
#
# (\begin{bmatrix}
#
# B - C \\
#  B + C
#
# \end{bmatrix}^T
#
# \begin{bmatrix}
# \tilde{V} \\
# \tilde{U}
# \end{bmatrix}
#
# e^{\tilde{S} \frac{t}{\tau}} e^{\frac{\lambda t}{2 \tau}})^T
#
#
#
#
# $$

# %% [markdown]
# Simplifying:
#
# $$
#
# \frac{1}{2}
#
# \begin{bmatrix}
#
# \tilde{V} e^{\tilde{S} \frac{t}{\tau}} e^{\frac{\lambda t}{2 \tau}} (B^T -  C^T) \\
#
# \tilde{U} e^{\tilde{S} \frac{t}{\tau}}e^{\frac{\lambda t}{2 \tau}} (B^T + C^T)
#
#
# \end{bmatrix}
#
#
#
# (8 A(0)^{-1} +
#
#
# \begin{bmatrix}
#
# \tilde{V} e^{\tilde{S} \frac{t}{\tau}} e^{\frac{\lambda t}{2 \tau}} (B^T -  C^T) \\
#
# \tilde{U} e^{\tilde{S} \frac{t}{\tau}}e^{\frac{\lambda t}{2 \tau}} (B^T + C^T)
#
#
# \end{bmatrix}^T
#
# X(t)
#
# \begin{bmatrix}
#
# \tilde{V} e^{\tilde{S} \frac{t}{\tau}} e^{\frac{\lambda t}{2 \tau}} (B^T -  C^T)  \\
#
# \tilde{U} e^{\tilde{S} \frac{t}{\tau}}e^{\frac{\lambda t}{2 \tau}} (B^T + C^T)
#
#
# \end{bmatrix} )^{-1}
#
#
# \begin{bmatrix}
#
# \tilde{V} e^{\tilde{S} \frac{t}{\tau}} e^{\frac{\lambda t}{2 \tau}} (B^T -  C^T)  \\
#
# \tilde{U} e^{\tilde{S} \frac{t}{\tau}}e^{\frac{\lambda t}{2 \tau}} (B^T + C^T)
#
#
# \end{bmatrix}^T
#
#
#
# $$

# %% [markdown]
# Define $B = e^{-\frac{\lambda t} {2 \tau}} U^T \tilde{U} + e^{\frac{\lambda t} {2 \tau}} V^T \tilde{V}$ and $C = e^{-\frac{\lambda t} {2 \tau}} U^T \tilde{U} - e^{\frac{\lambda t} {2 \tau}} V^T \tilde{V}$
#
# Then the equation becomes:
#
# Left side becomes:
#
# $$
# \frac{1}{2} \begin{bmatrix}
#
# \tilde{V} (e^{\tilde{S} \frac{t}{\tau}} B^T +  e^{- \tilde{S} \frac{t}{\tau}} C^T) \sqrt{A(0)} R^T \\
#
# \tilde{U} (e^{\tilde{S} \frac{t}{\tau}} B^T -  e^{- \tilde{S} \frac{t}{\tau}} C^T) \sqrt{A(0)} R^T
#
# \end{bmatrix}
# $$
#
# Centre becomes:
#
# $$
#
# I + \frac{1}{8} \begin{bmatrix}
#
# \tilde{V} (e^{\tilde{S} \frac{t}{\tau}} B^T +  e^{\tilde{S} \frac{t}{\tau}} C^T) \sqrt{A(0)} R^T \\
#
# \tilde{U} (e^{\tilde{S} \frac{t}{\tau}} B^T -  e^{\tilde{S} \frac{t}{\tau}} C^T) \sqrt{A(0)} R^T
#
# \end{bmatrix}^T
#
# X(t)
#
# \begin{bmatrix}
#
# \tilde{V} (e^{\tilde{S} \frac{t}{\tau}} B^T +  e^{\tilde{S} \frac{t}{\tau}} C^T) \sqrt{A(0)} R^T \\
#
# \tilde{U} (e^{\tilde{S} \frac{t}{\tau}} B^T -  e^{\tilde{S} \frac{t}{\tau}} C^T) \sqrt{A(0)} R^T
#
# \end{bmatrix}
# $$
#
# So whole thing becomes:
#
# $$
#
# \frac{1}{2} \begin{bmatrix}
#
# \tilde{V} (e^{\tilde{S} \frac{t}{\tau}} B^T +  e^{\tilde{S} \frac{t}{\tau}} C^T) \sqrt{A(0)} R^T \\
#
# \tilde{U} (e^{\tilde{S} \frac{t}{\tau}} B^T -  e^{\tilde{S} \frac{t}{\tau}} C^T) \sqrt{A(0)} R^T
#
# \end{bmatrix}
#
# (I + \frac{1}{8} \begin{bmatrix}
#
# \tilde{V} (e^{\tilde{S} \frac{t}{\tau}} B^T +  e^{\tilde{S} \frac{t}{\tau}} C^T) \sqrt{A(0)} R^T \\
#
# \tilde{U} (e^{\tilde{S} \frac{t}{\tau}} B^T -  e^{\tilde{S} \frac{t}{\tau}} C^T) \sqrt{A(0)} R^T
#
# \end{bmatrix}^T
#
# X(t)
#
# \begin{bmatrix}
#
# \tilde{V} (e^{\tilde{S} \frac{t}{\tau}} B^T +  e^{\tilde{S} \frac{t}{\tau}} C^T) \sqrt{A(0)} R^T \\
#
# \tilde{U} (e^{\tilde{S} \frac{t}{\tau}} B^T -  e^{\tilde{S} \frac{t}{\tau}} C^T) \sqrt{A(0)} R^T
#
# \end{bmatrix})^{-1}
#
# \frac{1}{2} \begin{bmatrix}
#
# \tilde{V} (e^{\tilde{S} \frac{t}{\tau}} B^T +  e^{\tilde{S} \frac{t}{\tau}} C^T) \sqrt{A(0)} R^T \\
#
# \tilde{U} (e^{\tilde{S} \frac{t}{\tau}} B^T -  e^{\tilde{S} \frac{t}{\tau}} C^T) \sqrt{A(0)} R^T
#
# \end{bmatrix}^T
#
#
# $$
#
# Which is equal to:
#
# $$
#
# \frac{1}{2} \begin{bmatrix}
#
# \tilde{V} (e^{\tilde{S} \frac{t}{\tau}} B^T +  e^{\tilde{S} \frac{t}{\tau}} C^T) \sqrt{A(0)} R^T \\
#
# \tilde{U} (e^{\tilde{S} \frac{t}{\tau}} B^T -  e^{\tilde{S} \frac{t}{\tau}} C^T) \sqrt{A(0)} R^T
#
# \end{bmatrix}
#
# (8I + \begin{bmatrix}
#
# \tilde{V} (e^{\tilde{S} \frac{t}{\tau}} B^T +  e^{\tilde{S} \frac{t}{\tau}} C^T) \sqrt{A(0)} R^T \\
#
# \tilde{U} (e^{\tilde{S} \frac{t}{\tau}} B^T -  e^{\tilde{S} \frac{t}{\tau}} C^T) \sqrt{A(0)} R^T
#
# \end{bmatrix}^T
#
# X(t)
#
# \begin{bmatrix}
#
# \tilde{V} (e^{\tilde{S} \frac{t}{\tau}} B^T +  e^{\tilde{S} \frac{t}{\tau}} C^T) \sqrt{A(0)} R^T \\
#
# \tilde{U} (e^{\tilde{S} \frac{t}{\tau}} B^T -  e^{\tilde{S} \frac{t}{\tau}} C^T) \sqrt{A(0)} R^T
#
# \end{bmatrix})^{-1}
#
# \begin{bmatrix}
#
# \tilde{V} (e^{\tilde{S} \frac{t}{\tau}} B^T +  e^{\tilde{S} \frac{t}{\tau}} C^T) \sqrt{A(0)} R^T \\
#
# \tilde{U} (e^{\tilde{S} \frac{t}{\tau}} B^T -  e^{\tilde{S} \frac{t}{\tau}} C^T) \sqrt{A(0)} R^T
#
# \end{bmatrix}^T
#
#
# $$
#
# Taking A's and R's inside the inverse:
#
# $$
#
# \begin{bmatrix}
# \tilde{V} (e^{\tilde{S} \frac{t}{\tau}} B^T +  e^{\tilde{S} \frac{t}{\tau}} C^T) \\
#
# \tilde{U} (e^{\tilde{S} \frac{t}{\tau}} B^T -  e^{\tilde{S} \frac{t}{\tau}} C^T)
#
# \end{bmatrix}
#
# ( 8 A(0)^{-1} + A(0)^{-\frac{1}{2}} R^T \begin{bmatrix}
#
# \tilde{V} (e^{\tilde{S} \frac{t}{\tau}} B^T +  e^{\tilde{S} \frac{t}{\tau}} C^T) \sqrt{A(0)} R^T \\
#
# \tilde{U} (e^{\tilde{S} \frac{t}{\tau}} B^T -  e^{\tilde{S} \frac{t}{\tau}} C^T) \sqrt{A(0)} R^T
#
# \end{bmatrix}^T
#
# X(t)
#
# \begin{bmatrix}
#
# \tilde{V} (e^{\tilde{S} \frac{t}{\tau}} B^T +  e^{\tilde{S} \frac{t}{\tau}} C^T) \sqrt{A(0)} R^T \\
#
# \tilde{U} (e^{\tilde{S} \frac{t}{\tau}} B^T -  e^{\tilde{S} \frac{t}{\tau}} C^T) \sqrt{A(0)} R^T
#
# \end{bmatrix}  R A(0)^{-\frac{1}{2}})^{-1}
#
# \begin{bmatrix}
#
# \tilde{V} (e^{\tilde{S} \frac{t}{\tau}} B^T +  e^{\tilde{S} \frac{t}{\tau}} C^T)\\
#
# \tilde{U} (e^{\tilde{S} \frac{t}{\tau}} B^T -  e^{\tilde{S} \frac{t}{\tau}} C^T)
#
# \end{bmatrix}^T
# $$
#
# Simplifying:
#
# $$
#
# \begin{bmatrix}
# \tilde{V} (e^{\tilde{S} \frac{t}{\tau}} B^T +  e^{\tilde{S} \frac{t}{\tau}} C^T) \\
#
# \tilde{U} (e^{\tilde{S} \frac{t}{\tau}} B^T -  e^{\tilde{S} \frac{t}{\tau}} C^T)
#
# \end{bmatrix}
#
# ( 8 A(0)^{-1} + \begin{bmatrix}
#
# \tilde{V} (e^{\tilde{S} \frac{t}{\tau}} B^T +  e^{\tilde{S} \frac{t}{\tau}} C^T) \\
#
# \tilde{U} (e^{\tilde{S} \frac{t}{\tau}} B^T -  e^{\tilde{S} \frac{t}{\tau}} C^T)
#
# \end{bmatrix}^T
#
# X(t)
#
# \begin{bmatrix}
#
# \tilde{V} (e^{\tilde{S} \frac{t}{\tau}} B^T +  e^{\tilde{S} \frac{t}{\tau}} C^T) \\
#
# \tilde{U} (e^{\tilde{S} \frac{t}{\tau}} B^T -  e^{\tilde{S} \frac{t}{\tau}} C^T)
#
# \end{bmatrix})^{-1}
#
# \begin{bmatrix}
#
# \tilde{V} (e^{\tilde{S} \frac{t}{\tau}} B^T +  e^{\tilde{S} \frac{t}{\tau}} C^T) \\
#
# \tilde{U} (e^{\tilde{S} \frac{t}{\tau}} B^T -  e^{\tilde{S} \frac{t}{\tau}} C^T)
#
# \end{bmatrix}^T
# $$

# %% [markdown]
# The problem is that I haven't been able to expand the thing inside, hard to take the inverse of X(t) in a nice way.
#
# Also note that B and C are functions of t as well if $\lambda$ is not 0.
#
# As I take the limit of t it is not obvious what this converges to, maybe I can thinkj about that later.
#
# The goal is to always have negative exponentials, try to rearrange so that is the case

# %% [markdown]
# TODO:
#
# REWRITE REST OF EQUATION, MIDDLE PART DOESNT MATTER THAT MUCH
#
# MAKE B AND C MORE GENERAL, STEPS SHOULD BE THE SAME AFTER THAT

# %% [markdown]
# Q(0) ^ T (exp X exp - X) Q(0) =
